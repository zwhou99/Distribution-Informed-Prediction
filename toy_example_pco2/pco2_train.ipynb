# %%
import os
import time
import warnings

import torch
import pickle
import numpy as np
import xarray as xr
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

from utils import read_xarray
from model import SimpleTanhNN
from sklearn_som.som import SOM

warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
# Check for GPU availability and set the device
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %% [markdown]
# # Data Preparation

# %%
# Define constants and hyperparameters
data_type = "CESM"
data_num = "001"
batch_size = 32
num_hiddens = 100
normalize = True
y_normalize = False
base_learning_rate = 1e-2
lr = base_learning_rate * batch_size / 256
weight_decay = 0
test_method = "future"
test_ratio = 0.2
early_stopping = True
patience = 10

# %%
rdir = os.getcwd()
dir_name = rdir + "/data"

# %%
# Load data using the custom read_xarray function
chl, mld, sss, sst, u10, xco2, icefrac, patm, pco2 = read_xarray(dir_name, data_type, data_num)

# Apply masks and preprocessing to the data
socat_mask = pco2.pCO2_socat.data[:420, ::-1] > 0.5

sst = sst.SST.data[:420, ::-1]
chl = chl.Chl.data[:420, ::-1]
mld = mld.MLD.data[:420, ::-1]
sss = sss.SSS.data[:420, ::-1]
patm = patm.pATM.data[:420, ::-1]
xco2 = xco2.XCO2.data[:420, np.newaxis, np.newaxis]
xco2 = np.broadcast_to(xco2, (420, 180, 360))
pco2 = pco2.pCO2.data[:420, ::-1]

land_mask = xr.open_dataset(dir_name + "/land.nc").mask.data[::-1]
land_mask = (~np.isnan(land_mask))[np.newaxis, :, :]
land_mask = np.broadcast_to(land_mask, (420, 180, 360))
land_mask = land_mask & (pco2 > 0.5) & (chl > 0)

socat_mask = land_mask & socat_mask

# %%
# Function to remove seasonal patterns from a 3D data array
def deseasonalize_3d_array(data):
    n_months = 12
    n_years = data.shape[0] // n_months
    latitudes = data.shape[1]
    longitudes = data.shape[2]

    reshaped_data = data.reshape(n_years, n_months, latitudes, longitudes)
    monthly_means = reshaped_data.mean(axis=0)
    deseasonalized_data = (reshaped_data - monthly_means).reshape(data.shape[0], latitudes, longitudes)

    return deseasonalized_data

# %%
# Deseasonalize data
sst_ds = deseasonalize_3d_array(sst)
chl_ds = deseasonalize_3d_array(chl)
mld_ds = deseasonalize_3d_array(mld)
sss_ds = deseasonalize_3d_array(sss)
xco2_ds = deseasonalize_3d_array(xco2)
logchl = np.log(chl)
logmld = np.log(mld)

# %%
X = np.stack((sst, logchl, logmld, sss, xco2, sst_ds, chl_ds, mld_ds, sss_ds, xco2_ds), axis=-1)

if normalize:
    X_mean = np.mean(X[land_mask], axis=0)
    X_std = np.std(X[land_mask], axis=0)
    X = (X - X_mean) / X_std

# %%
# Split the data into training and testing sets
if test_method == 'future':
    l = len(X)
    X_train = X[:int(l * (1 - test_ratio))]
    X_test = X[int(l * (1 - test_ratio)):]
    socat_mask_train = socat_mask[:int(l * (1 - test_ratio))]
    socat_mask_test = socat_mask[int(l * (1 - test_ratio)):]
    y_train = pco2[:int(l * (1 - test_ratio))]
    y_test = pco2[int(l * (1 - test_ratio)):]
    land_mask_train = land_mask[:int(l * (1 - test_ratio))]
    land_mask_test = land_mask[int(l * (1 - test_ratio)):]
else:
    raise NotImplementedError

# %% [markdown]
# # Train SOM

# %%
X_pixel_train = X_train[land_mask_train]
X_pixel_test = X_test[land_mask_test]
y_pixel_train = y_train[land_mask_train]
y_pixel_test = y_test[land_mask_test]

# %%
# Train the Self-Organizing Map (SOM) model
SOM_model = SOM(m=4, n=4, dim=4)
SOM_input = np.stack((sst, logmld, sss, patm), axis=-1)[land_mask]
SOM_model.fit(SOM_input)

# %%
with open('SOM_model.pkl', 'wb') as f:
    pickle.dump(SOM_model, f)

# %% [markdown]
# # Prepare Dataset for FFN

# %%
SOM_socat_train = np.stack((sst, logmld, sss, patm), axis=-1)
SOM_socat_test = SOM_socat_train[int(l * (1 - test_ratio)):][socat_mask_test]
SOM_socat_train = SOM_socat_train[:int(l * (1 - test_ratio))][socat_mask_train]

X_socat_train = X_train[socat_mask_train]
X_socat_test = X_test[socat_mask_test]
y_socat_train = y_train[socat_mask_train]
y_socat_test = y_test[socat_mask_test]

# %%
province_train = SOM_model.predict(SOM_socat_train)
province_test = SOM_model.predict(SOM_socat_test)

# %%
# Prepare datasets and dataloaders for each province
train_datasets = []
test_datasets = []
train_iters = []
test_iters = []
y_means = []
y_stds = []

for province_id in range(16):
    train_mask = (province_train == province_id)
    test_mask = (province_test == province_id)

    temp_y = y_socat_train[train_mask]
    y_means.append(np.mean(temp_y))
    y_stds.append(np.std(temp_y))
    train_datasets.append(TensorDataset(
        torch.tensor(X_socat_train[train_mask], dtype=torch.float64),
        torch.tensor(temp_y, dtype=torch.float64)
    ))
    test_datasets.append(TensorDataset(
        torch.tensor(X_socat_test[test_mask], dtype=torch.float64),
        torch.tensor(y_socat_test[test_mask], dtype=torch.float64)
    ))

    train_iters.append(DataLoader(train_datasets[-1], batch_size=batch_size, shuffle=True))
    test_iters.append(DataLoader(test_datasets[-1], batch_size=batch_size, shuffle=False))

# %%
# Initialize neural networks and optimizers for each province
FFNs = []
optims = []
for i in range(16):
    FFNs.append(SimpleTanhNN(10, num_hiddens, 1).double().to(device))
    optims.append(torch.optim.SGD(FFNs[-1].parameters(), lr=lr, weight_decay=weight_decay))

criterion = nn.MSELoss(reduction='mean')
train_losses = []
test_losses = []

# %% [markdown]
# # Train FFN

# %%
# Function to train the neural network with early stopping
def train(net, train_iter, test_iter, num_epochs, optimizer, criterion, y_normalize, y_mean, y_std, device,
          ltrain, ltest, early_stopping, patience):

    def train_one_epoch(net, device, data_iter, optimizer, criterion, y_normalize, y_mean, y_std):
        train_l_sum, train_l2_sum = torch.zeros(1, device=device), torch.zeros(1, device=device)

        for X, y in data_iter:
            l = X.size(0)
            X = X.to(device)
            ypred = net(X)

            if y_normalize:
                y_norm = (y - y_mean) / y_std
                loss = criterion(ypred, torch.unsqueeze(y_norm, 1).to(device))
                ypred = ypred * y_std + y_mean
                loss2 = criterion(ypred, torch.unsqueeze(y, 1).to(device))
                train_l2_sum += loss2.detach() * l
            else:
                loss = criterion(ypred, torch.unsqueeze(y, 1).to(device))

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            train_l_sum += loss.detach() * l

        return train_l_sum.cpu().item(), train_l2_sum.cpu().item()

    def evaluate_accuracy(net, device, data_iter, criterion, y_normalize, y_mean, y_std):
        loss_sum, loss2_sum = torch.zeros(1, device=device), torch.zeros(1, device=device)
        with torch.no_grad():
            net.eval()
            for X, y in data_iter:
                l = X.size(0)
                X = X.to(device)
                ypred = net(X)
                if y_normalize:
                    y_norm = (y - y_mean) / y_std
                    loss = criterion(ypred, torch.unsqueeze(y_norm, 1).to(device))
                    ypred = ypred * y_std + y_mean
                    loss2 = criterion(ypred, torch.unsqueeze(y, 1).to(device))
                    loss2_sum += loss2.detach() * l
                else:
                    loss = criterion(ypred, torch.unsqueeze(y, 1).to(device))

                loss_sum += loss.detach() * l
            net.train()
        return loss_sum.cpu().item(), loss2_sum.cpu().item()

    optimizer.zero_grad()

    best_test_loss = float('inf')
    epochs_no_improve = 0
    best_state = None

    for epoch in range(num_epochs):
        start = time.time()

        train_loss, train_loss2 = train_one_epoch(net, device, train_iter, optimizer, criterion, y_normalize,
                                                  y_mean, y_std)
        train_loss /= ltrain
        train_loss2 /= ltrain

        if test_iter is not None:
            test_loss, test_loss2 = evaluate_accuracy(net, device, test_iter, criterion, y_normalize, y_mean, y_std)
            test_loss /= ltest
            test_loss2 /= ltest
        else:
            test_loss, test_loss2 = float('nan'), float('nan')

        print("epoch %d: train loss %.4f, train loss2 %.4f, test loss %.4f, test loss2 %.4f time %.1f sec" %
              (epoch + 1, train_loss, train_loss2, test_loss, test_loss2, time.time() - start))

        # Early stopping logic
        if early_stopping:
            if test_loss < best_test_loss - 1e-6:
                best_test_loss = test_loss
                epochs_no_improve = 0
                best_state = net.state_dict()  # Save best model
            else:
                epochs_no_improve += 1
                if epochs_no_improve >= patience:
                    print(f"Early stopping at epoch {epoch+1}")
                    if best_state is not None:
                        net.load_state_dict(best_state)  # Restore best model
                    break

    return train_loss, train_loss2, test_loss, test_loss2

# %%
# Train the neural networks
for i in range(0, 16):
    print('Training province: ', i + 1)
    ltrain = np.sum(province_train == i)
    ltest = np.sum(province_test == i)
    train_loss, train_loss2, test_loss, test_loss2 = train(FFNs[i], train_iters[i], test_iters[i], 100,
                                                           optims[i], criterion, y_normalize,
                                                           y_means[i], y_stds[i], device, ltrain, ltest, early_stopping, patience)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
# Out:
# Training province:  1
# epoch 1: train loss 2608.2866, train loss2 0.0000, test loss 1020.5171, test loss2 0.0000 time 0.7 sec
# epoch 2: train loss 689.7533, train loss2 0.0000, test loss 1229.3075, test loss2 0.0000 time 0.6 sec
# epoch 3: train loss 630.2300, train loss2 0.0000, test loss 1131.6838, test loss2 0.0000 time 0.6 sec
# epoch 4: train loss 588.2818, train loss2 0.0000, test loss 1214.2479, test loss2 0.0000 time 0.6 sec
# epoch 5: train loss 561.8119, train loss2 0.0000, test loss 1240.0379, test loss2 0.0000 time 0.6 sec
# epoch 6: train loss 541.3283, train loss2 0.0000, test loss 1078.4394, test loss2 0.0000 time 0.7 sec
# epoch 7: train loss 523.0714, train loss2 0.0000, test loss 1469.5763, test loss2 0.0000 time 0.6 sec
# epoch 8: train loss 504.1027, train loss2 0.0000, test loss 1290.1295, test loss2 0.0000 time 0.6 sec
# epoch 9: train loss 490.7410, train loss2 0.0000, test loss 1185.7010, test loss2 0.0000 time 0.6 sec
# epoch 10: train loss 480.9048, train loss2 0.0000, test loss 1100.5932, test loss2 0.0000 time 0.6 sec
# epoch 11: train loss 470.2224, train loss2 0.0000, test loss 1157.4492, test loss2 0.0000 time 0.8 sec
# Early stopping at epoch 11
# Training province:  2
# epoch 1: train loss 6837.8088, train loss2 0.0000, test loss 509.8520, test loss2 0.0000 time 0.3 sec
# epoch 2: train loss 271.0291, train loss2 0.0000, test loss 409.2853, test loss2 0.0000 time 0.3 sec
# epoch 3: train loss 208.4779, train loss2 0.0000, test loss 328.5815, test loss2 0.0000 time 0.3 sec
# epoch 4: train loss 182.7925, train loss2 0.0000, test loss 283.6775, test loss2 0.0000 time 0.3 sec
# epoch 5: train loss 162.3201, train loss2 0.0000, test loss 297.4634, test loss2 0.0000 time 0.2 sec
# epoch 6: train loss 145.2309, train loss2 0.0000, test loss 336.8048, test loss2 0.0000 time 0.3 sec
# epoch 7: train loss 143.3070, train loss2 0.0000, test loss 329.1644, test loss2 0.0000 time 0.3 sec
# epoch 8: train loss 132.8030, train loss2 0.0000, test loss 301.5848, test loss2 0.0000 time 0.3 sec
# epoch 9: train loss 130.7245, train loss2 0.0000, test loss 359.3735, test loss2 0.0000 time 0.3 sec
# epoch 10: train loss 124.0612, train loss2 0.0000, test loss 317.8164, test loss2 0.0000 time 0.3 sec
# epoch 11: train loss 121.4909, train loss2 0.0000, test loss 300.5257, test loss2 0.0000 time 0.3 sec
# epoch 12: train loss 117.0161, train loss2 0.0000, test loss 361.5385, test loss2 0.0000 time 0.3 sec
# epoch 13: train loss 114.4565, train loss2 0.0000, test loss 314.5330, test loss2 0.0000 time 0.3 sec
# epoch 14: train loss 113.9521, train loss2 0.0000, test loss 399.6713, test loss2 0.0000 time 0.3 sec
# Early stopping at epoch 14
# Training province:  3
# epoch 1: train loss 4275.7610, train loss2 0.0000, test loss 1277.8362, test loss2 0.0000 time 0.6 sec
# epoch 2: train loss 614.6006, train loss2 0.0000, test loss 863.4600, test loss2 0.0000 time 0.6 sec
# epoch 3: train loss 510.5690, train loss2 0.0000, test loss 969.3280, test loss2 0.0000 time 0.6 sec
# epoch 4: train loss 472.9891, train loss2 0.0000, test loss 675.6277, test loss2 0.0000 time 0.6 sec
# epoch 5: train loss 446.4697, train loss2 0.0000, test loss 670.5992, test loss2 0.0000 time 0.7 sec
# epoch 6: train loss 435.8337, train loss2 0.0000, test loss 757.8846, test loss2 0.0000 time 0.6 sec
# epoch 7: train loss 418.0850, train loss2 0.0000, test loss 943.7707, test loss2 0.0000 time 0.6 sec
# epoch 8: train loss 406.8615, train loss2 0.0000, test loss 703.2011, test loss2 0.0000 time 0.6 sec
# epoch 9: train loss 401.7172, train loss2 0.0000, test loss 637.0349, test loss2 0.0000 time 0.7 sec
# epoch 10: train loss 395.4766, train loss2 0.0000, test loss 575.0211, test loss2 0.0000 time 0.6 sec
# epoch 11: train loss 382.5499, train loss2 0.0000, test loss 625.4413, test loss2 0.0000 time 0.7 sec
# epoch 12: train loss 380.8486, train loss2 0.0000, test loss 766.8430, test loss2 0.0000 time 0.7 sec
# epoch 13: train loss 372.6849, train loss2 0.0000, test loss 711.3944, test loss2 0.0000 time 0.6 sec
# epoch 14: train loss 369.9162, train loss2 0.0000, test loss 651.4475, test loss2 0.0000 time 0.7 sec
# epoch 15: train loss 370.7706, train loss2 0.0000, test loss 650.6089, test loss2 0.0000 time 0.7 sec
# epoch 16: train loss 368.9014, train loss2 0.0000, test loss 571.7497, test loss2 0.0000 time 0.7 sec
# epoch 17: train loss 360.0046, train loss2 0.0000, test loss 653.3485, test loss2 0.0000 time 0.6 sec
# epoch 18: train loss 359.9106, train loss2 0.0000, test loss 587.5651, test loss2 0.0000 time 0.6 sec
# epoch 19: train loss 359.0689, train loss2 0.0000, test loss 596.1047, test loss2 0.0000 time 0.6 sec
# epoch 20: train loss 354.8516, train loss2 0.0000, test loss 684.7277, test loss2 0.0000 time 0.7 sec
# epoch 21: train loss 349.3098, train loss2 0.0000, test loss 598.2683, test loss2 0.0000 time 0.6 sec
# epoch 22: train loss 342.3740, train loss2 0.0000, test loss 691.9702, test loss2 0.0000 time 0.6 sec
# epoch 23: train loss 340.6257, train loss2 0.0000, test loss 764.7549, test loss2 0.0000 time 0.6 sec
# epoch 24: train loss 338.5418, train loss2 0.0000, test loss 573.0665, test loss2 0.0000 time 0.6 sec
# epoch 25: train loss 337.3212, train loss2 0.0000, test loss 645.9195, test loss2 0.0000 time 0.6 sec
# epoch 26: train loss 335.3091, train loss2 0.0000, test loss 623.7974, test loss2 0.0000 time 0.6 sec
# Early stopping at epoch 26
# Training province:  4
# epoch 1: train loss 3052.6511, train loss2 0.0000, test loss 432.7248, test loss2 0.0000 time 0.7 sec
# epoch 2: train loss 474.2648, train loss2 0.0000, test loss 396.4470, test loss2 0.0000 time 0.8 sec
# epoch 3: train loss 450.7194, train loss2 0.0000, test loss 401.5968, test loss2 0.0000 time 0.7 sec
# epoch 4: train loss 440.5902, train loss2 0.0000, test loss 403.1601, test loss2 0.0000 time 0.7 sec
# epoch 5: train loss 424.3960, train loss2 0.0000, test loss 418.6052, test loss2 0.0000 time 0.7 sec
# epoch 6: train loss 407.4345, train loss2 0.0000, test loss 498.5285, test loss2 0.0000 time 0.7 sec
# epoch 7: train loss 398.2886, train loss2 0.0000, test loss 400.9347, test loss2 0.0000 time 0.7 sec
# epoch 8: train loss 387.8400, train loss2 0.0000, test loss 416.0646, test loss2 0.0000 time 0.8 sec
# epoch 9: train loss 378.8935, train loss2 0.0000, test loss 487.0445, test loss2 0.0000 time 0.7 sec
# epoch 10: train loss 374.0227, train loss2 0.0000, test loss 498.1355, test loss2 0.0000 time 0.7 sec
# epoch 11: train loss 362.4065, train loss2 0.0000, test loss 476.0477, test loss2 0.0000 time 0.7 sec
# epoch 12: train loss 356.0088, train loss2 0.0000, test loss 489.1261, test loss2 0.0000 time 0.7 sec
# Early stopping at epoch 12
# Training province:  5
# epoch 1: train loss 3979.2212, train loss2 0.0000, test loss 841.3381, test loss2 0.0000 time 0.6 sec
# epoch 2: train loss 628.7413, train loss2 0.0000, test loss 1374.0892, test loss2 0.0000 time 0.6 sec
# epoch 3: train loss 550.4006, train loss2 0.0000, test loss 946.4653, test loss2 0.0000 time 0.5 sec
# epoch 4: train loss 507.0182, train loss2 0.0000, test loss 722.5665, test loss2 0.0000 time 0.5 sec
# epoch 5: train loss 468.9055, train loss2 0.0000, test loss 1001.5821, test loss2 0.0000 time 0.5 sec
# epoch 6: train loss 444.0575, train loss2 0.0000, test loss 1119.1381, test loss2 0.0000 time 0.6 sec
# epoch 7: train loss 423.7455, train loss2 0.0000, test loss 652.9579, test loss2 0.0000 time 0.6 sec
# epoch 8: train loss 407.4365, train loss2 0.0000, test loss 1094.7023, test loss2 0.0000 time 0.6 sec
# epoch 9: train loss 392.8778, train loss2 0.0000, test loss 1156.4792, test loss2 0.0000 time 0.6 sec
# epoch 10: train loss 384.6065, train loss2 0.0000, test loss 592.0818, test loss2 0.0000 time 0.6 sec
# epoch 11: train loss 373.0134, train loss2 0.0000, test loss 850.9861, test loss2 0.0000 time 0.6 sec
# epoch 12: train loss 354.8705, train loss2 0.0000, test loss 1556.3533, test loss2 0.0000 time 0.6 sec
# epoch 13: train loss 350.0181, train loss2 0.0000, test loss 1558.4803, test loss2 0.0000 time 0.6 sec
# epoch 14: train loss 340.5968, train loss2 0.0000, test loss 1424.1661, test loss2 0.0000 time 0.6 sec
# epoch 15: train loss 326.8645, train loss2 0.0000, test loss 1002.4077, test loss2 0.0000 time 0.6 sec
# epoch 16: train loss 322.1518, train loss2 0.0000, test loss 835.8719, test loss2 0.0000 time 0.6 sec
# epoch 17: train loss 312.2663, train loss2 0.0000, test loss 1100.9616, test loss2 0.0000 time 0.6 sec
# epoch 18: train loss 306.4744, train loss2 0.0000, test loss 921.6376, test loss2 0.0000 time 0.6 sec
# epoch 19: train loss 301.8650, train loss2 0.0000, test loss 811.8987, test loss2 0.0000 time 0.6 sec
# epoch 20: train loss 291.3650, train loss2 0.0000, test loss 1351.4493, test loss2 0.0000 time 0.6 sec
# Early stopping at epoch 20
# Training province:  6
# epoch 1: train loss 2862.4598, train loss2 0.0000, test loss 831.8102, test loss2 0.0000 time 0.9 sec
# epoch 2: train loss 466.6913, train loss2 0.0000, test loss 643.1955, test loss2 0.0000 time 0.9 sec
# epoch 3: train loss 398.2891, train loss2 0.0000, test loss 666.1912, test loss2 0.0000 time 1.0 sec
# epoch 4: train loss 373.8577, train loss2 0.0000, test loss 564.5293, test loss2 0.0000 time 0.9 sec
# epoch 5: train loss 348.5543, train loss2 0.0000, test loss 731.5809, test loss2 0.0000 time 0.9 sec
# epoch 6: train loss 327.0280, train loss2 0.0000, test loss 588.2962, test loss2 0.0000 time 0.9 sec
# epoch 7: train loss 320.1989, train loss2 0.0000, test loss 789.1297, test loss2 0.0000 time 0.9 sec
# epoch 8: train loss 314.0617, train loss2 0.0000, test loss 568.8572, test loss2 0.0000 time 0.9 sec
# epoch 9: train loss 297.1493, train loss2 0.0000, test loss 549.5583, test loss2 0.0000 time 0.9 sec
# epoch 10: train loss 292.6473, train loss2 0.0000, test loss 597.1146, test loss2 0.0000 time 0.9 sec
# epoch 11: train loss 283.0623, train loss2 0.0000, test loss 983.0779, test loss2 0.0000 time 0.9 sec
# epoch 12: train loss 274.6618, train loss2 0.0000, test loss 544.6030, test loss2 0.0000 time 0.8 sec
# epoch 13: train loss 274.4548, train loss2 0.0000, test loss 561.0171, test loss2 0.0000 time 0.8 sec
# epoch 14: train loss 266.0043, train loss2 0.0000, test loss 690.0028, test loss2 0.0000 time 0.9 sec
# epoch 15: train loss 262.3338, train loss2 0.0000, test loss 632.4228, test loss2 0.0000 time 0.8 sec
# epoch 16: train loss 259.4550, train loss2 0.0000, test loss 729.4037, test loss2 0.0000 time 0.8 sec
# epoch 17: train loss 258.6479, train loss2 0.0000, test loss 543.9128, test loss2 0.0000 time 0.9 sec
# epoch 18: train loss 248.5182, train loss2 0.0000, test loss 659.3069, test loss2 0.0000 time 0.8 sec
# epoch 19: train loss 250.4642, train loss2 0.0000, test loss 670.8421, test loss2 0.0000 time 0.8 sec
# epoch 20: train loss 246.9977, train loss2 0.0000, test loss 714.6255, test loss2 0.0000 time 0.8 sec
# epoch 21: train loss 242.7681, train loss2 0.0000, test loss 740.6694, test loss2 0.0000 time 0.9 sec
# epoch 22: train loss 243.5987, train loss2 0.0000, test loss 685.9476, test loss2 0.0000 time 0.9 sec
# epoch 23: train loss 240.1710, train loss2 0.0000, test loss 730.5295, test loss2 0.0000 time 0.9 sec
# epoch 24: train loss 240.7397, train loss2 0.0000, test loss 840.9527, test loss2 0.0000 time 0.9 sec
# epoch 25: train loss 238.6063, train loss2 0.0000, test loss 703.6086, test loss2 0.0000 time 0.9 sec
# epoch 26: train loss 235.1149, train loss2 0.0000, test loss 652.7217, test loss2 0.0000 time 0.9 sec
# epoch 27: train loss 237.3928, train loss2 0.0000, test loss 696.4925, test loss2 0.0000 time 0.9 sec
# Early stopping at epoch 27
# Training province:  7
# epoch 1: train loss 3653.0548, train loss2 0.0000, test loss 529.1604, test loss2 0.0000 time 0.7 sec
# epoch 2: train loss 436.5955, train loss2 0.0000, test loss 459.5074, test loss2 0.0000 time 0.8 sec
# epoch 3: train loss 375.5244, train loss2 0.0000, test loss 417.7081, test loss2 0.0000 time 0.7 sec
# epoch 4: train loss 350.3748, train loss2 0.0000, test loss 421.0462, test loss2 0.0000 time 0.7 sec
# epoch 5: train loss 336.5049, train loss2 0.0000, test loss 427.6936, test loss2 0.0000 time 0.7 sec
# epoch 6: train loss 326.7301, train loss2 0.0000, test loss 501.4696, test loss2 0.0000 time 0.7 sec
# epoch 7: train loss 319.1068, train loss2 0.0000, test loss 412.7093, test loss2 0.0000 time 0.7 sec
# epoch 8: train loss 312.3164, train loss2 0.0000, test loss 389.4872, test loss2 0.0000 time 0.7 sec
# epoch 9: train loss 307.4361, train loss2 0.0000, test loss 415.1864, test loss2 0.0000 time 0.7 sec
# epoch 10: train loss 300.1660, train loss2 0.0000, test loss 450.9393, test loss2 0.0000 time 0.7 sec
# epoch 11: train loss 296.1183, train loss2 0.0000, test loss 413.4592, test loss2 0.0000 time 0.7 sec
# epoch 12: train loss 290.3030, train loss2 0.0000, test loss 408.4010, test loss2 0.0000 time 0.7 sec
# epoch 13: train loss 287.1802, train loss2 0.0000, test loss 394.2379, test loss2 0.0000 time 0.7 sec
# epoch 14: train loss 281.6243, train loss2 0.0000, test loss 442.3121, test loss2 0.0000 time 0.8 sec
# epoch 15: train loss 277.6721, train loss2 0.0000, test loss 432.0131, test loss2 0.0000 time 0.8 sec
# epoch 16: train loss 272.2216, train loss2 0.0000, test loss 457.0146, test loss2 0.0000 time 0.7 sec
# epoch 17: train loss 268.5033, train loss2 0.0000, test loss 422.8981, test loss2 0.0000 time 0.7 sec
# epoch 18: train loss 265.0478, train loss2 0.0000, test loss 440.9426, test loss2 0.0000 time 0.7 sec
# Early stopping at epoch 18
# Training province:  8
# epoch 1: train loss 3123.4101, train loss2 0.0000, test loss 622.1631, test loss2 0.0000 time 0.8 sec
# epoch 2: train loss 724.8768, train loss2 0.0000, test loss 488.7507, test loss2 0.0000 time 0.8 sec
# epoch 3: train loss 615.1715, train loss2 0.0000, test loss 452.5997, test loss2 0.0000 time 0.9 sec
# epoch 4: train loss 548.6041, train loss2 0.0000, test loss 592.8477, test loss2 0.0000 time 0.8 sec
# epoch 5: train loss 501.6295, train loss2 0.0000, test loss 500.4873, test loss2 0.0000 time 0.8 sec
# epoch 6: train loss 467.2960, train loss2 0.0000, test loss 441.4264, test loss2 0.0000 time 0.9 sec
# epoch 7: train loss 442.1815, train loss2 0.0000, test loss 490.5837, test loss2 0.0000 time 0.8 sec
# epoch 8: train loss 420.1210, train loss2 0.0000, test loss 545.7650, test loss2 0.0000 time 0.8 sec
# epoch 9: train loss 403.7366, train loss2 0.0000, test loss 586.7774, test loss2 0.0000 time 0.8 sec
# epoch 10: train loss 392.3983, train loss2 0.0000, test loss 549.4707, test loss2 0.0000 time 0.8 sec
# epoch 11: train loss 379.2267, train loss2 0.0000, test loss 514.4100, test loss2 0.0000 time 0.9 sec
# epoch 12: train loss 371.5751, train loss2 0.0000, test loss 682.6827, test loss2 0.0000 time 0.9 sec
# epoch 13: train loss 366.5084, train loss2 0.0000, test loss 566.0579, test loss2 0.0000 time 0.8 sec
# epoch 14: train loss 359.3791, train loss2 0.0000, test loss 511.8060, test loss2 0.0000 time 0.8 sec
# epoch 15: train loss 356.2697, train loss2 0.0000, test loss 538.3470, test loss2 0.0000 time 0.8 sec
# epoch 16: train loss 349.6236, train loss2 0.0000, test loss 693.9450, test loss2 0.0000 time 0.8 sec
# Early stopping at epoch 16
# Training province:  9
# epoch 1: train loss 3449.3540, train loss2 0.0000, test loss 1142.4394, test loss2 0.0000 time 0.8 sec
# epoch 2: train loss 561.2797, train loss2 0.0000, test loss 797.1041, test loss2 0.0000 time 0.8 sec
# epoch 3: train loss 468.8159, train loss2 0.0000, test loss 689.2243, test loss2 0.0000 time 0.8 sec
# epoch 4: train loss 424.9470, train loss2 0.0000, test loss 705.5226, test loss2 0.0000 time 0.8 sec
# epoch 5: train loss 404.4768, train loss2 0.0000, test loss 899.4024, test loss2 0.0000 time 0.7 sec
# epoch 6: train loss 385.7532, train loss2 0.0000, test loss 731.0272, test loss2 0.0000 time 0.8 sec
# epoch 7: train loss 373.3315, train loss2 0.0000, test loss 783.8774, test loss2 0.0000 time 0.8 sec
# epoch 8: train loss 361.9084, train loss2 0.0000, test loss 695.0660, test loss2 0.0000 time 0.8 sec
# epoch 9: train loss 352.7995, train loss2 0.0000, test loss 1239.7767, test loss2 0.0000 time 0.8 sec
# epoch 10: train loss 349.7247, train loss2 0.0000, test loss 680.4024, test loss2 0.0000 time 0.8 sec
# epoch 11: train loss 341.6919, train loss2 0.0000, test loss 683.8802, test loss2 0.0000 time 0.8 sec
# epoch 12: train loss 336.0072, train loss2 0.0000, test loss 816.2350, test loss2 0.0000 time 0.8 sec
# epoch 13: train loss 329.8241, train loss2 0.0000, test loss 667.4325, test loss2 0.0000 time 0.7 sec
# epoch 14: train loss 322.7907, train loss2 0.0000, test loss 811.9583, test loss2 0.0000 time 0.7 sec
# epoch 15: train loss 323.6601, train loss2 0.0000, test loss 706.7890, test loss2 0.0000 time 0.8 sec
# epoch 16: train loss 316.7403, train loss2 0.0000, test loss 901.5006, test loss2 0.0000 time 0.8 sec
# epoch 17: train loss 311.7884, train loss2 0.0000, test loss 722.5187, test loss2 0.0000 time 0.8 sec
# epoch 18: train loss 309.8584, train loss2 0.0000, test loss 985.1569, test loss2 0.0000 time 0.8 sec
# epoch 19: train loss 307.6686, train loss2 0.0000, test loss 804.1684, test loss2 0.0000 time 0.7 sec
# epoch 20: train loss 307.4398, train loss2 0.0000, test loss 661.3975, test loss2 0.0000 time 0.7 sec
# epoch 21: train loss 300.1573, train loss2 0.0000, test loss 792.3104, test loss2 0.0000 time 0.8 sec
# epoch 22: train loss 300.8506, train loss2 0.0000, test loss 855.1470, test loss2 0.0000 time 0.8 sec
# epoch 23: train loss 297.2333, train loss2 0.0000, test loss 684.2553, test loss2 0.0000 time 0.8 sec
# epoch 24: train loss 294.4554, train loss2 0.0000, test loss 813.6148, test loss2 0.0000 time 0.9 sec
# epoch 25: train loss 290.0725, train loss2 0.0000, test loss 680.0150, test loss2 0.0000 time 0.8 sec
# epoch 26: train loss 293.8508, train loss2 0.0000, test loss 723.8238, test loss2 0.0000 time 0.8 sec
# epoch 27: train loss 288.5614, train loss2 0.0000, test loss 674.5578, test loss2 0.0000 time 0.8 sec
# epoch 28: train loss 284.0440, train loss2 0.0000, test loss 763.6891, test loss2 0.0000 time 0.8 sec
# epoch 29: train loss 285.6612, train loss2 0.0000, test loss 727.2361, test loss2 0.0000 time 0.8 sec
# epoch 30: train loss 285.5671, train loss2 0.0000, test loss 714.5400, test loss2 0.0000 time 0.8 sec
# Early stopping at epoch 30
# Training province:  10
# epoch 1: train loss 5131.8772, train loss2 0.0000, test loss 849.9098, test loss2 0.0000 time 0.5 sec
# epoch 2: train loss 571.9892, train loss2 0.0000, test loss 722.5709, test loss2 0.0000 time 0.5 sec
# epoch 3: train loss 467.1156, train loss2 0.0000, test loss 637.8240, test loss2 0.0000 time 0.6 sec
# epoch 4: train loss 431.1498, train loss2 0.0000, test loss 596.7439, test loss2 0.0000 time 0.5 sec
# epoch 5: train loss 414.3656, train loss2 0.0000, test loss 609.9400, test loss2 0.0000 time 0.5 sec
# epoch 6: train loss 397.0426, train loss2 0.0000, test loss 568.6313, test loss2 0.0000 time 0.6 sec
# epoch 7: train loss 389.2033, train loss2 0.0000, test loss 593.1723, test loss2 0.0000 time 0.5 sec
# epoch 8: train loss 377.5225, train loss2 0.0000, test loss 591.0856, test loss2 0.0000 time 0.6 sec
# epoch 9: train loss 369.3614, train loss2 0.0000, test loss 664.6224, test loss2 0.0000 time 0.6 sec
# epoch 10: train loss 366.5066, train loss2 0.0000, test loss 584.5876, test loss2 0.0000 time 0.5 sec
# epoch 11: train loss 365.4824, train loss2 0.0000, test loss 629.1020, test loss2 0.0000 time 0.5 sec
# epoch 12: train loss 356.5089, train loss2 0.0000, test loss 711.2523, test loss2 0.0000 time 0.5 sec
# epoch 13: train loss 352.9385, train loss2 0.0000, test loss 723.8450, test loss2 0.0000 time 0.5 sec
# epoch 14: train loss 350.9375, train loss2 0.0000, test loss 712.5166, test loss2 0.0000 time 0.5 sec
# epoch 15: train loss 345.1750, train loss2 0.0000, test loss 717.4047, test loss2 0.0000 time 0.5 sec
# epoch 16: train loss 341.2370, train loss2 0.0000, test loss 704.1025, test loss2 0.0000 time 0.5 sec
# Early stopping at epoch 16
# Training province:  11
# epoch 1: train loss 3213.1532, train loss2 0.0000, test loss 766.7388, test loss2 0.0000 time 1.1 sec
# epoch 2: train loss 782.8417, train loss2 0.0000, test loss 733.9221, test loss2 0.0000 time 1.1 sec
# epoch 3: train loss 664.3303, train loss2 0.0000, test loss 688.3595, test loss2 0.0000 time 1.1 sec
# epoch 4: train loss 619.5403, train loss2 0.0000, test loss 683.6430, test loss2 0.0000 time 1.0 sec
# epoch 5: train loss 582.3082, train loss2 0.0000, test loss 631.0402, test loss2 0.0000 time 1.0 sec
# epoch 6: train loss 554.2612, train loss2 0.0000, test loss 671.1333, test loss2 0.0000 time 1.1 sec
# epoch 7: train loss 533.7775, train loss2 0.0000, test loss 558.6302, test loss2 0.0000 time 1.0 sec
# epoch 8: train loss 512.5759, train loss2 0.0000, test loss 803.0535, test loss2 0.0000 time 1.0 sec
# epoch 9: train loss 496.7091, train loss2 0.0000, test loss 776.6991, test loss2 0.0000 time 1.1 sec
# epoch 10: train loss 487.7031, train loss2 0.0000, test loss 839.5257, test loss2 0.0000 time 1.1 sec
# epoch 11: train loss 475.0852, train loss2 0.0000, test loss 703.1901, test loss2 0.0000 time 1.1 sec
# epoch 12: train loss 464.9039, train loss2 0.0000, test loss 752.2434, test loss2 0.0000 time 1.2 sec
# epoch 13: train loss 455.0997, train loss2 0.0000, test loss 681.7134, test loss2 0.0000 time 1.1 sec
# epoch 14: train loss 444.2600, train loss2 0.0000, test loss 766.3545, test loss2 0.0000 time 1.1 sec
# epoch 15: train loss 438.6852, train loss2 0.0000, test loss 803.5056, test loss2 0.0000 time 1.1 sec
# epoch 16: train loss 428.7113, train loss2 0.0000, test loss 801.2487, test loss2 0.0000 time 1.1 sec
# epoch 17: train loss 421.4405, train loss2 0.0000, test loss 1016.9555, test loss2 0.0000 time 1.1 sec
# Early stopping at epoch 17
# Training province:  12
# epoch 1: train loss 2226.1975, train loss2 0.0000, test loss 656.8688, test loss2 0.0000 time 1.4 sec
# epoch 2: train loss 790.8918, train loss2 0.0000, test loss 513.9318, test loss2 0.0000 time 1.4 sec
# epoch 3: train loss 739.7920, train loss2 0.0000, test loss 794.1533, test loss2 0.0000 time 1.4 sec
# epoch 4: train loss 668.4765, train loss2 0.0000, test loss 672.9084, test loss2 0.0000 time 1.5 sec
# epoch 5: train loss 617.2059, train loss2 0.0000, test loss 999.8679, test loss2 0.0000 time 1.4 sec
# epoch 6: train loss 564.5311, train loss2 0.0000, test loss 586.2281, test loss2 0.0000 time 1.3 sec
# epoch 7: train loss 509.6279, train loss2 0.0000, test loss 438.0248, test loss2 0.0000 time 1.3 sec
# epoch 8: train loss 481.1759, train loss2 0.0000, test loss 447.5714, test loss2 0.0000 time 1.3 sec
# epoch 9: train loss 459.1770, train loss2 0.0000, test loss 670.8305, test loss2 0.0000 time 1.2 sec
# epoch 10: train loss 441.2266, train loss2 0.0000, test loss 542.4289, test loss2 0.0000 time 1.4 sec
# epoch 11: train loss 429.7657, train loss2 0.0000, test loss 550.9140, test loss2 0.0000 time 1.3 sec
# epoch 12: train loss 420.4479, train loss2 0.0000, test loss 408.0692, test loss2 0.0000 time 1.4 sec
# epoch 13: train loss 414.5327, train loss2 0.0000, test loss 663.7692, test loss2 0.0000 time 1.4 sec
# epoch 14: train loss 410.8435, train loss2 0.0000, test loss 633.1992, test loss2 0.0000 time 1.4 sec
# epoch 15: train loss 405.4201, train loss2 0.0000, test loss 1066.7659, test loss2 0.0000 time 1.4 sec
# epoch 16: train loss 397.4187, train loss2 0.0000, test loss 557.9053, test loss2 0.0000 time 1.3 sec
# epoch 17: train loss 390.8122, train loss2 0.0000, test loss 728.4360, test loss2 0.0000 time 1.4 sec
# epoch 18: train loss 390.1278, train loss2 0.0000, test loss 484.2457, test loss2 0.0000 time 1.4 sec
# epoch 19: train loss 386.5299, train loss2 0.0000, test loss 937.7544, test loss2 0.0000 time 1.3 sec
# epoch 20: train loss 381.6233, train loss2 0.0000, test loss 598.9892, test loss2 0.0000 time 1.4 sec
# epoch 21: train loss 379.4439, train loss2 0.0000, test loss 617.1975, test loss2 0.0000 time 1.3 sec
# epoch 22: train loss 378.2408, train loss2 0.0000, test loss 510.1066, test loss2 0.0000 time 1.4 sec
# Early stopping at epoch 22
# Training province:  13
# epoch 1: train loss 5398.1296, train loss2 0.0000, test loss 864.3889, test loss2 0.0000 time 0.4 sec
# epoch 2: train loss 599.0051, train loss2 0.0000, test loss 702.9622, test loss2 0.0000 time 0.4 sec
# epoch 3: train loss 529.6423, train loss2 0.0000, test loss 586.9791, test loss2 0.0000 time 0.4 sec
# epoch 4: train loss 492.0684, train loss2 0.0000, test loss 576.3734, test loss2 0.0000 time 0.4 sec
# epoch 5: train loss 467.6929, train loss2 0.0000, test loss 617.6960, test loss2 0.0000 time 0.4 sec
# epoch 6: train loss 444.2684, train loss2 0.0000, test loss 467.8707, test loss2 0.0000 time 0.4 sec
# epoch 7: train loss 425.8838, train loss2 0.0000, test loss 451.5652, test loss2 0.0000 time 0.4 sec
# epoch 8: train loss 414.5549, train loss2 0.0000, test loss 549.7591, test loss2 0.0000 time 0.4 sec
# epoch 9: train loss 395.7428, train loss2 0.0000, test loss 577.3824, test loss2 0.0000 time 0.4 sec
# epoch 10: train loss 389.6276, train loss2 0.0000, test loss 507.1907, test loss2 0.0000 time 0.4 sec
# epoch 11: train loss 378.7397, train loss2 0.0000, test loss 510.2601, test loss2 0.0000 time 0.4 sec
# epoch 12: train loss 374.7942, train loss2 0.0000, test loss 421.8404, test loss2 0.0000 time 0.4 sec
# epoch 13: train loss 368.0452, train loss2 0.0000, test loss 520.5574, test loss2 0.0000 time 0.4 sec
# epoch 14: train loss 362.3481, train loss2 0.0000, test loss 513.3287, test loss2 0.0000 time 0.4 sec
# epoch 15: train loss 354.2514, train loss2 0.0000, test loss 418.5046, test loss2 0.0000 time 0.4 sec
# epoch 16: train loss 355.7358, train loss2 0.0000, test loss 471.9123, test loss2 0.0000 time 0.4 sec
# epoch 17: train loss 351.0832, train loss2 0.0000, test loss 485.1596, test loss2 0.0000 time 0.4 sec
# epoch 18: train loss 346.3989, train loss2 0.0000, test loss 430.3857, test loss2 0.0000 time 0.4 sec
# epoch 19: train loss 349.8492, train loss2 0.0000, test loss 480.5202, test loss2 0.0000 time 0.4 sec
# epoch 20: train loss 346.2534, train loss2 0.0000, test loss 434.3144, test loss2 0.0000 time 0.4 sec
# epoch 21: train loss 344.2564, train loss2 0.0000, test loss 443.9438, test loss2 0.0000 time 0.4 sec
# epoch 22: train loss 344.1384, train loss2 0.0000, test loss 462.1063, test loss2 0.0000 time 0.4 sec
# epoch 23: train loss 340.1596, train loss2 0.0000, test loss 440.6323, test loss2 0.0000 time 0.5 sec
# epoch 24: train loss 335.7081, train loss2 0.0000, test loss 437.9402, test loss2 0.0000 time 0.4 sec
# epoch 25: train loss 334.2894, train loss2 0.0000, test loss 471.9719, test loss2 0.0000 time 0.5 sec
# Early stopping at epoch 25
# Training province:  14
# epoch 1: train loss 4023.6866, train loss2 0.0000, test loss 642.0461, test loss2 0.0000 time 0.7 sec
# epoch 2: train loss 531.6060, train loss2 0.0000, test loss 483.5328, test loss2 0.0000 time 0.7 sec
# epoch 3: train loss 472.0937, train loss2 0.0000, test loss 434.5833, test loss2 0.0000 time 0.7 sec
# epoch 4: train loss 444.3224, train loss2 0.0000, test loss 412.2039, test loss2 0.0000 time 0.7 sec
# epoch 5: train loss 426.1561, train loss2 0.0000, test loss 419.1064, test loss2 0.0000 time 0.6 sec
# epoch 6: train loss 409.1734, train loss2 0.0000, test loss 407.8187, test loss2 0.0000 time 0.7 sec
# epoch 7: train loss 394.0587, train loss2 0.0000, test loss 406.4753, test loss2 0.0000 time 0.6 sec
# epoch 8: train loss 379.3955, train loss2 0.0000, test loss 457.7553, test loss2 0.0000 time 0.6 sec
# epoch 9: train loss 366.1708, train loss2 0.0000, test loss 412.1293, test loss2 0.0000 time 0.7 sec
# epoch 10: train loss 355.4737, train loss2 0.0000, test loss 402.2570, test loss2 0.0000 time 0.6 sec
# epoch 11: train loss 346.4622, train loss2 0.0000, test loss 433.0826, test loss2 0.0000 time 0.7 sec
# epoch 12: train loss 335.5883, train loss2 0.0000, test loss 433.4907, test loss2 0.0000 time 0.7 sec
# epoch 13: train loss 325.6098, train loss2 0.0000, test loss 559.1770, test loss2 0.0000 time 0.7 sec
# epoch 14: train loss 316.9032, train loss2 0.0000, test loss 535.6960, test loss2 0.0000 time 0.6 sec
# epoch 15: train loss 310.2835, train loss2 0.0000, test loss 480.0273, test loss2 0.0000 time 0.6 sec
# epoch 16: train loss 305.8118, train loss2 0.0000, test loss 521.6500, test loss2 0.0000 time 0.6 sec
# epoch 17: train loss 298.3201, train loss2 0.0000, test loss 513.5791, test loss2 0.0000 time 0.7 sec
# epoch 18: train loss 295.0555, train loss2 0.0000, test loss 497.8354, test loss2 0.0000 time 0.7 sec
# epoch 19: train loss 288.8455, train loss2 0.0000, test loss 605.6717, test loss2 0.0000 time 0.7 sec
# epoch 20: train loss 282.2198, train loss2 0.0000, test loss 605.2210, test loss2 0.0000 time 0.6 sec
# Early stopping at epoch 20
# Training province:  15
# epoch 1: train loss 3837.6376, train loss2 0.0000, test loss 736.9817, test loss2 0.0000 time 0.8 sec
# epoch 2: train loss 1196.7729, train loss2 0.0000, test loss 842.5269, test loss2 0.0000 time 0.8 sec
# epoch 3: train loss 1100.4442, train loss2 0.0000, test loss 850.8109, test loss2 0.0000 time 0.8 sec
# epoch 4: train loss 1030.3735, train loss2 0.0000, test loss 768.0028, test loss2 0.0000 time 0.8 sec
# epoch 5: train loss 988.2884, train loss2 0.0000, test loss 820.4844, test loss2 0.0000 time 0.8 sec
# epoch 6: train loss 942.7887, train loss2 0.0000, test loss 763.3431, test loss2 0.0000 time 0.9 sec
# epoch 7: train loss 896.8778, train loss2 0.0000, test loss 810.5431, test loss2 0.0000 time 0.8 sec
# epoch 8: train loss 869.3449, train loss2 0.0000, test loss 793.1911, test loss2 0.0000 time 0.8 sec
# epoch 9: train loss 844.1605, train loss2 0.0000, test loss 815.7949, test loss2 0.0000 time 0.8 sec
# epoch 10: train loss 812.3114, train loss2 0.0000, test loss 823.3825, test loss2 0.0000 time 0.8 sec
# epoch 11: train loss 787.4835, train loss2 0.0000, test loss 818.7034, test loss2 0.0000 time 0.8 sec
# Early stopping at epoch 11
# Training province:  16
# epoch 1: train loss 1159.3860, train loss2 0.0000, test loss 394.2967, test loss2 0.0000 time 3.3 sec
# epoch 2: train loss 463.1242, train loss2 0.0000, test loss 412.6867, test loss2 0.0000 time 3.3 sec
# epoch 3: train loss 424.7708, train loss2 0.0000, test loss 385.7756, test loss2 0.0000 time 3.3 sec
# epoch 4: train loss 405.2922, train loss2 0.0000, test loss 478.2028, test loss2 0.0000 time 3.4 sec
# epoch 5: train loss 390.7749, train loss2 0.0000, test loss 476.3677, test loss2 0.0000 time 3.3 sec
# epoch 6: train loss 380.6301, train loss2 0.0000, test loss 474.1455, test loss2 0.0000 time 3.2 sec
# epoch 7: train loss 373.5294, train loss2 0.0000, test loss 530.8930, test loss2 0.0000 time 3.3 sec
# epoch 8: train loss 369.0648, train loss2 0.0000, test loss 653.6298, test loss2 0.0000 time 3.3 sec
# epoch 9: train loss 364.3543, train loss2 0.0000, test loss 589.2072, test loss2 0.0000 time 3.2 sec
# epoch 10: train loss 362.0992, train loss2 0.0000, test loss 674.1070, test loss2 0.0000 time 3.3 sec
# epoch 11: train loss 353.8148, train loss2 0.0000, test loss 540.8580, test loss2 0.0000 time 3.3 sec
# epoch 12: train loss 347.2771, train loss2 0.0000, test loss 580.2006, test loss2 0.0000 time 3.4 sec
# epoch 13: train loss 341.6366, train loss2 0.0000, test loss 669.3538, test loss2 0.0000 time 3.3 sec
# Early stopping at epoch 13

# %% [markdown]
# # Prepare Dataset for Calibration

# %%
all_features = np.stack((sst, logmld, sss, patm), axis=-1)
reshaped_features = all_features.reshape(-1, 4)
all_provinces_flat = SOM_model.predict(reshaped_features)
all_provinces = all_provinces_flat.reshape((420, 180, 360))
all_provinces[~land_mask] = -1

# %%
# Save the province predictions
with open('all_provinces.pkl', 'wb') as f:
    pickle.dump(all_provinces, f)

# %%
raw_y_hat = np.zeros((420, 180, 360))
with torch.no_grad():
    for province in range(len(FFNs)):
        mask = (all_provinces == province)
        indices = np.argwhere(mask)

        if indices.size > 0:
            batch_indices = indices[:, 0], indices[:, 1], indices[:, 2]
            batch_inputs = torch.tensor(X[batch_indices], dtype=torch.float64, device=device)
            batch_outputs = FFNs[province](batch_inputs).cpu().numpy()
            raw_y_hat[mask] = batch_outputs.flatten()

# %%
# Save the predictions
with open('raw_y_hat.pkl', 'wb') as f:
    pickle.dump(raw_y_hat, f)

# %% [markdown]
# # Prepare CESM 002 Dataset

# %%
# Load additional data for further predictions
chl_CESM002, mld_CESM002, sss_CESM002, sst_CESM002, u10_CESM002, xco2_CESM002, icefrac_CESM002,\
patm_CESM002, pco2_CESM002 = read_xarray(dir_name, 'CESM', '002')
pco2_CESM002 = pco2_CESM002.pCO2.data[:420, ::-1]
sst_CESM002 = sst_CESM002.SST.data[:420, ::-1]
mld_CESM002 = mld_CESM002.MLD.data[:420, ::-1]
sss_CESM002 = sss_CESM002.SSS.data[:420, ::-1]
patm_CESM002 = patm_CESM002.pATM.data[:420, ::-1]
logmld_CESM002 = np.log(mld_CESM002)

# %%
all_features_CESM002 = np.stack((sst_CESM002, logmld_CESM002, sss_CESM002, patm_CESM002), axis=-1)
reshaped_features_CESM002 = all_features_CESM002.reshape(-1, 4)
all_provinces_flat_CESM002 = SOM_model.predict(reshaped_features_CESM002)
all_provinces_CESM002 = all_provinces_flat_CESM002.reshape((420, 180, 360))
all_provinces_CESM002[~land_mask] = -1

# %%
# Save the province predictions for the additional data
with open('all_provinces_CESM002.pkl', 'wb') as f:
    pickle.dump(all_provinces_CESM002, f)
